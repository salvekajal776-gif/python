# %%
# printing with labels

# %%
print("name:",student_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1735/1607562815.py in <cell line: 0>()
# ----> 1 print("name:",student_name)
#
# NameError: name 'student_name' is not defined

# %%
student_name="kajal"

# %%
print("name:",student_name)
# Out:
# name: kajal

# %%
# changing varible values

# %%
student_name="zombie"

# %%
print("name:",student_name)
# Out:
# name: zombie

# %%
x,y,z=100,200,300

# %%
print("x=",x)
# Out:
# x= 100

# %%
print("y=",y)
# Out:
# y= 200

# %%
print("z=",z)
# Out:
# z= 300

# %%
# same value to multiple variables

# %%
maths=science=english=90

# %%
print("maths:",maths)
# Out:
# maths: 90

# %%
print("science:",science)
# Out:
# science: 90

# %%
print("english:",english)
# Out:
# english: 90

# %%
# invalid variable name

# %%
2name="rahul"
# Out:
#   File "/tmp/ipykernel_1735/1307543727.py", line 1
#     2name="rahul"
#     ^
# SyntaxError: invalid decimal literal

# %%
student=name="kajal"

# %%
full name="zombie"
# Out:
#   File "/tmp/ipykernel_1735/1737160167.py", line 1
#     full name="zombie"
#          ^
# SyntaxError: invalid syntax

# %%
class="kajal"
# Out:
#   File "/tmp/ipykernel_1735/445795187.py", line 1
#     class="kajal"
#          ^
# SyntaxError: invalid syntax

# %%
#dynamic typing

# %%
value=100

# %%
print(value)
# Out:
# 100

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
value="python"

# %%
print(value)
# Out:
# python

# %%
print(type(value))
# Out:
# <class 'str'>

# %%
# integer means whole number

# %%
age=21

# %%
print(age,tyoe(age))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1735/2088012195.py in <cell line: 0>()
# ----> 1 print(age,tyoe(age))
#
# NameError: name 'tyoe' is not defined

# %% [markdown]
# 1.   List item
# 2.   List item

# %%
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
#integer operation

# %%
a=25
b=10

# %%
# addtion

# %%
#string

# %%
first_name="kajal"

# %%
last_name="zombie"

# %%
course_name="python"

# %%
print("first name:",first_name)
# Out:
# first name: kajal

# %%
print("last name:",last_name)
# Out:
# last name: zombie

# %%
print(type(last_name))
# Out:
# <class 'str'>

# %%
#srting repetiting

# %%
word="python"

# %%
print(word*3)
# Out:
# pythonpythonpython

# %%
word="python"

# %%
print(word *3 )
# Out:
# pythonpythonpython

# %%
#string indexing

# %%
language="python"

# %%
language[0]
# Out:
# 'p'

# %%
language[1]
# Out:
# 'y'

# %%
language[-1]
# Out:
# 'n'

# %%
language[-2]
# Out:
# 'o'

# %%
language[-3]
# Out:
# 'h'

# %%
language[2]
# Out:
# 't'

# %%
#string slicing

# %%
language="python programing"

# %%
language[0:6]
# Out:
# 'python'

# %%
language[7:18]
# Out:
# 'programing'

# %%
language[:6]
# Out:
# 'python'

# %%
language[4]
# Out:
# 'o'

# %%
#string methods

# %%
message ="welcom to python programing"

# %%
message.upper()
# Out:
# 'WELCOM TO PYTHON PROGRAMING'

# %%
message.lower()
# Out:
# <function str.lower()>

# %%
message.title()
# Out:
# <function str.title()>

# %%
message.capitalize()
# Out:
# 'Welcom to python programing'

# %%
len(message)
# Out:
# 27

# %%
#replace
#used to replace a word

# %%
text="i like python"

# %%
new_text = text.replace("python","java")

# %%
print(new_text)
# Out:
# i like java

# %%
#split

# %%
text ="apple banan mango"

# %%
word=text.split()

# %%
print(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1735/403926419.py in <cell line: 0>()
# ----> 1 print(words)
#
# NameError: name 'words' is not defined
