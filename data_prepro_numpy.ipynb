# %%
# NumPy

# %%
# %pip install numpy
# Out:
# ...
#
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
# Array is a powerful grid used to store a collection of data—usually numbers—where every item is of the same type.

# %%
# An array is a data structure consisting of a collection of elements of the same data type, stored in 
# contiguous memory locations and identified by at least one array index or key

# %%
# Creating Arrays

# %%
# 1D Array (also known as a Vector).

# %%
sample_array = np.array([1, 2, 3, 4])

# %%
sample_array
# Out:
# array([1, 2, 3, 4])

# %%
# 2D Array (a matrix) with 2 rows and 2 columns.

# %%
sample_array_2 = np.array([[1, 2], [3, 4]])

# %%
sample_array_2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
# 3D tensor is a collection of 2D matrices stacked together, 
# represented in NumPy as a nested array with three axes: depth, rows, and columns.

# %%
# 3D Tensor (2 matrices, each with 2 rows and 2 columns)

# %%
sample_tensor_3 = np.array([
    [[1, 2], [3, 4]], # First matrix
    [[5, 6], [7, 8]]  # Second matrix
])

# %%
sample_tensor_3
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
# Array Properties

# %%
sample_array = np.array([[1,2,3],[4,5,6]])

# %%
sample_array.shape # (rows, columns)
# Out:
# (2, 3)

# %%
# Dimension (also called an axis) refers to the number of directions needed to find a specific piece of data.

# 0-D Array (Scalar): A single number (e.g., 5). It has no dimensions.
# 1-D Array (Vector): A simple list of numbers (e.g., [1, 2, 3]). You only need one index to find a value.
# 2-D Array (Matrix): A table with rows and columns. You need two indices (row, column) to find a value.
# 3-D Array (Tensor): A stack of tables (like a book of spreadsheets). You need three indices (page, row, column) to find a value.

# %%
sample_array.ndim # dimensions
# Out:
# 2

# %%
sample_array.size # total elements
# Out:
# 6

# %%
sample_array.dtype # data type
# Out:
# dtype('int64')

# %%
# Special Arrays

# %%
np.zeros((2,3))   # all zer
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))    # all ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(0,10,2) # range
# Out:
# array([0, 2, 4, 6, 8])

# %%
# np.arange(start, stop, step)
# Focuses on the interval between numbers.
# Result: [0, 2, 4, 6, 8]
# Behavior: Similar to Python's range. It starts at 0 and adds 2 repeatedly. It excludes the stop value (10).
# Best Use: When you know exactly how far apart you want your numbers to be.

# %%
np.linspace(0,1,5) # equally spaced values
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
# np.linspace(start, stop, num)
# Focuses on the total count of numbers.
# Result: [0. , 0.25, 0.5 , 0.75, 1. ]
# Behavior: "Linear Space." It squeezes exactly 5 numbers between 0 and 1. It includes the stop value (1) by default.
# Best Use: When you need a specific number of points to create a smooth line or graph.

# %%
# Indexing & Slicing

# %%
sample_array = np.array([10,20,30,40])

# %%
sample_array[0]     # first element
# Out:
# np.int64(10)

# %%
sample_array[1:3]   # slicing
# The simplest way to remember slicing is: [Start : Stop before]
# Out:
# array([20, 30])

# %%
# 2D indexing

# %%
sample_array = np.array([[1,2,3],[4,5,6]])

# %%
sample_array[0,1]   # row 0, col 1
# Out:
# np.int64(2)

# %%
# Array Operations

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %%
a + b
# Out:
# array([5, 7, 9])

# %%
a - b
# Out:
# array([-3, -3, -3])

# %%
a * b
# Out:
# array([ 4, 10, 18])

# %%
a / b
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
# Mathematical Functions

# %%
sample_array = np.array([1,4,9])

# %%
np.sqrt(sample_array)
# Out:
# array([1., 2., 3.])

# %%
# In NumPy, exponential refers to raising the constant e𝑒
# (Euler's number, approximately 2.718) to the power of each element in your array.

# %%
np.exp(sample_array)
# Out:
# array([2.71828183e+00, 5.45981500e+01, 8.10308393e+03])

# %%
np.log(sample_array)
# Out:
# array([0.        , 1.38629436, 2.19722458])

# %%
# Statistical Functions

# %%
sample_array = np.array([1,2,3,4,5])

# %%
np.mean(sample_array)
# Out:
# np.float64(3.0)

# %%
np.median(sample_array)
# Out:
# np.float64(3.0)

# %%
np.std(sample_array)
# Out:
# np.float64(1.4142135623730951)

# %%
np.sum(sample_array)
# Out:
# np.int64(15)

# %%
np.min(sample_array)
# Out:
# np.int64(1)

# %%
np.max(sample_array)
# Out:
# np.int64(5)

# %%
# Reshaping Arrays

# %%
# np.arange() generates an array of evenly spaced values within 
# a given interval, defined by a start (inclusive), stop (exclusive), and an optional step size.

# %%
sample_array = np.arange(6)

# %%
sample_array
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
reshaped = sample_array.reshape(2,3)

# %%
reshaped
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
# Flattening

# %%
sample_array = np.array([[1,2],[3,4]])

# %%
sample_array
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
sample_array.flatten()
# Out:
# array([1, 2, 3, 4])

# %%
# Joining Arrays

# %%
a = np.array([1,2])

# %%
b = np.array([3,4])

# %%
np.concatenate((a,b))
# Out:
# array([1, 2, 3, 4])

# %%
# Splitting Arrays

# %%
sample_array = np.array([1,2,3,4])

# %%
np.array_split(sample_array, 2)
# Out:
# [array([1, 2]), array([3, 4])]

# %%
# Sorting

# %%
sample_array = np.array([3,1,2])

# %%
np.sort(sample_array)
# Out:
# array([1, 2, 3])

# %%
# Searching

# %%
sample_array = np.array([1,2,3,4])

# %%
np.where(sample_array == 3)
# Out:
# (array([2]),)

# %%
# Random Module

# %%
np.random.rand(3)       # random floats
# Out:
# array([0.02380918, 0.32747256, 0.20799427])

# %%
np.random.randint(1,10,5) # random integers
# Out:
# array([3, 9, 4, 8, 3])

# %%
# Axis Concept

# %%
# In NumPy, Axis is just another word for Dimension. 
# You use axes to tell NumPy which direction to perform a calculation (like summing numbers).

# %%
sample_array = np.array([[1,2],[3,4]])

# %%
np.sum(sample_array, axis=0)  # column-wise
# Out:
# array([4, 6])

# %%
np.sum(sample_array, axis=1)  # row-wise
# Out:
# array([3, 7])

# %%
# NaN & Missing Values

# %%
# In NumPy, NaN stands for "Not a Number". 
# It is a special floating-point value used to represent missing or undefined data.

# %%
sample_array = np.array([1, np.nan, 3])

# %%
np.isnan(sample_array)
# Out:
# array([False,  True, False])

# %%
np.nanmean(sample_array)
# Out:
# np.float64(2.0)

# %%
# This code calculates the average of an array while ignoring any missing values (NaN).
# How it works:
# The Problem: If you use the regular np.mean(), any NaN in the data "breaks" the math, and the result will just be nan.
# The Fix: np.nanmean() treats the "holes" as if they don't exist. 
# It sums the available numbers and divides by the count of actual numbers (not the total size of the array).
